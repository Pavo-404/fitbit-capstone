# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/Pavly/Downloads/archive/mturkfitbit_export_4.12.16-5.12.16/Fitabase Data 4.12.16-5.12.16/dailyActivity_merged.csv')

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df.Id.nunique()
# Out:
# 33

# %%
cols = ['Id','ActivityDate','TotalSteps','VeryActiveMinutes','FairlyActiveMinutes','LightlyActiveMinutes','SedentaryMinutes','Calories' ]
df = df[cols]

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  VeryActiveMinutes  \
# 0    1503960366    4/12/2016       13162                 25
# 1    1503960366    4/13/2016       10735                 21
# 2    1503960366    4/14/2016       10460                 30
# 3    1503960366    4/15/2016        9762                 29
# 4    1503960366    4/16/2016       12669                 36
# ..          ...          ...         ...                ...
# 935  8877689391     5/8/2016       10686                 17
# 936  8877689391     5/9/2016       20226                 73
# 937  8877689391    5/10/2016       10733                 18
# 938  8877689391    5/11/2016       21420                 88
# 939  8877689391    5/12/2016        8064                 23
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# ...

# %%
df.rename(columns={'ActivityDate': 'Date'},inplace=True)
# Out:
# C:\Users\Pavly\AppData\Local\Temp\ipykernel_8760\866236168.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'ActivityDate': 'Date'},inplace=True)

# %%
df['TotalMimutes'] = df.VeryActiveMinutes + df.FairlyActiveMinutes + df.LightlyActiveMinutes +df.SedentaryMinutes
# Out:
# C:\Users\Pavly\AppData\Local\Temp\ipykernel_8760\50656373.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalMimutes'] = df.VeryActiveMinutes + df.FairlyActiveMinutes + df.LightlyActiveMinutes +df.SedentaryMinutes

# %%
df
# Out:
#              Id       Date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366  4/12/2016       13162                 25
# 1    1503960366  4/13/2016       10735                 21
# 2    1503960366  4/14/2016       10460                 30
# 3    1503960366  4/15/2016        9762                 29
# 4    1503960366  4/16/2016       12669                 36
# ..          ...        ...         ...                ...
# 935  8877689391   5/8/2016       10686                 17
# 936  8877689391   5/9/2016       20226                 73
# 937  8877689391  5/10/2016       10733                 18
# 938  8877689391  5/11/2016       21420                 88
# 939  8877689391  5/12/2016        8064                 23
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# ...

# %%
df["TotlaHours"] = round(df.TotalMimutes /60).astype(int)
# Out:
# C:\Users\Pavly\AppData\Local\Temp\ipykernel_8760\2079672219.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["TotlaHours"] = round(df.TotalMimutes /60).astype(int)

# %%
df
# Out:
#              Id       Date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366 2016-04-12       13162                 25
# 1    1503960366 2016-04-13       10735                 21
# 2    1503960366 2016-04-14       10460                 30
# 3    1503960366 2016-04-15        9762                 29
# 4    1503960366 2016-04-16       12669                 36
# ..          ...        ...         ...                ...
# 935  8877689391 2016-05-08       10686                 17
# 936  8877689391 2016-05-09       20226                 73
# 937  8877689391 2016-05-10       10733                 18
# 938  8877689391 2016-05-11       21420                 88
# 939  8877689391 2016-05-12        8064                 23
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    940 non-null    int64
#  1   Date                  940 non-null    datetime64[ns]
#  2   TotalSteps            940 non-null    int64
#  3   VeryActiveMinutes     940 non-null    int64
#  4   FairlyActiveMinutes   940 non-null    int64
#  5   LightlyActiveMinutes  940 non-null    int64
#  6   SedentaryMinutes      940 non-null    int64
#  7   Calories              940 non-null    int64
#  8   TotalMimutes          940 non-null    int64
#  9   TotlaHours            940 non-null    int32
#  10  DayOfWeek             940 non-null    object
#  11  DayOfWeek_Num         940 non-null    int64
# dtypes: datetime64[ns](1), int32(1), int64(9), object(1)
# memory usage: 84.6+ KB

# %%
df.Date = pd.to_datetime(df.Date)
# Out:
# C:\Users\Pavly\AppData\Local\Temp\ipykernel_8760\4238552302.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Date = pd.to_datetime(df.Date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    940 non-null    int64
#  1   Date                  940 non-null    datetime64[ns]
#  2   TotalSteps            940 non-null    int64
#  3   VeryActiveMinutes     940 non-null    int64
#  4   FairlyActiveMinutes   940 non-null    int64
#  5   LightlyActiveMinutes  940 non-null    int64
#  6   SedentaryMinutes      940 non-null    int64
#  7   Calories              940 non-null    int64
#  8   TotalMimutes          940 non-null    int64
#  9   TotlaHours            940 non-null    int32
#  10  DayOfWeek             940 non-null    object
#  11  DayOfWeek_Num         940 non-null    int64
# dtypes: datetime64[ns](1), int32(1), int64(9), object(1)
# memory usage: 84.6+ KB

# %%
import datetime as dt
df['DayOfWeek'] = df['Date'].dt.day_name()
df
# Out:
# C:\Users\Pavly\AppData\Local\Temp\ipykernel_8760\858174314.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DayOfWeek'] = df['Date'].dt.day_name()
#              Id       Date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366 2016-04-12       13162                 25
# 1    1503960366 2016-04-13       10735                 21
# 2    1503960366 2016-04-14       10460                 30
# 3    1503960366 2016-04-15        9762                 29
# 4    1503960366 2016-04-16       12669                 36
# ..          ...        ...         ...                ...
# 935  8877689391 2016-05-08       10686                 17
# 936  8877689391 2016-05-09       20226                 73
# ...

# %%
df.isnull().sum()
# Out:
# Id                      0
# Date                    0
# TotalSteps              0
# VeryActiveMinutes       0
# FairlyActiveMinutes     0
# LightlyActiveMinutes    0
# SedentaryMinutes        0
# Calories                0
# TotalMimutes            0
# TotlaHours              0
# DayOfWeek               0
# DayOfWeek_Num           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Id                      0
# Date                    0
# TotalSteps              0
# VeryActiveMinutes       0
# FairlyActiveMinutes     0
# LightlyActiveMinutes    0
# SedentaryMinutes        0
# Calories                0
# TotalMimutes            0
# TotlaHours              0
# DayOfWeek               0
# DayOfWeek_Num           0
# dtype: int64

# %%
df.describe()
# Out:
#                  Id                           Date    TotalSteps  \
# count  9.400000e+02                            940    940.000000
# mean   4.855407e+09  2016-04-26 06:53:37.021276672   7637.910638
# min    1.503960e+09            2016-04-12 00:00:00      0.000000
# 25%    2.320127e+09            2016-04-19 00:00:00   3789.750000
# 50%    4.445115e+09            2016-04-26 00:00:00   7405.500000
# 75%    6.962181e+09            2016-05-04 00:00:00  10727.000000
# max    8.877689e+09            2016-05-12 00:00:00  36019.000000
# std    2.424805e+09                            NaN   5087.150742
#
#        VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# count         940.000000           940.000000            940.000000
# mean           21.164894            13.564894            192.812766
# min             0.000000             0.000000              0.000000
# 25%             0.000000             0.000000            127.000000
# ...

# %%
plt.figure(figsize=((7,4)))
plt.hist(df.DayOfWeek,bins= 7 ,color='lightskyblue',width= 0.6)
plt.xlabel('Day of week')
plt.ylabel('Freq')
plt.title('Freq dy day ')
plt.show()

# %%
print(df['DayOfWeek'].dtype)
print(df['DayOfWeek'].unique())

# Define a mapping from day names to numerical values
day_mapping = {'Monday': 1, 'Tuesday': 2, 'Wednesday': 3, 'Thursday': 4, 'Friday': 5, 'Saturday': 6, 'Sunday': 7}

try:
    # Map the 'DayOfWeek' column to numerical values
    df['DayOfWeek_Num'] = df['DayOfWeek'].map(day_mapping)
    
    # Plot the histogram using the numerical column
    plt.figure(figsize=(6, 5))
    plt.hist(df['DayOfWeek_Num'], bins=7, color='lightskyblue', width=0.6)
    #plt.grid(True)
    plt.show()
    
except ValueError as e:
    print("Error:", e)
# Out:
# object
# ['Tuesday' 'Wednesday' 'Thursday' 'Friday' 'Saturday' 'Sunday' 'Monday']
# C:\Users\Pavly\AppData\Local\Temp\ipykernel_8760\3415032438.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DayOfWeek_Num'] = df['DayOfWeek'].map(day_mapping)

# %%
correlation_matrix = df.corr(method='pearson', numeric_only=True)

# %%
sns.heatmap(correlation_matrix)
# Out:
# <Axes: >

# %%
plt.figure(figsize=((8,7)))
plt.scatter(df.TotalSteps, df.Calories ,c =df.Calories)

Median_steps = 7405
Median_Calories =2134

plt.axhline(Median_Calories,color = 'blue',label="Median of cal")
plt.axvline(Median_steps,color='red',label="Median of steps")

plt.xlabel('steps')
plt.ylabel('Cal')

plt.title("cal by total steps")
plt.legend()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    940 non-null    int64
#  1   Date                  940 non-null    datetime64[ns]
#  2   TotalSteps            940 non-null    int64
#  3   VeryActiveMinutes     940 non-null    int64
#  4   FairlyActiveMinutes   940 non-null    int64
#  5   LightlyActiveMinutes  940 non-null    int64
#  6   SedentaryMinutes      940 non-null    int64
#  7   Calories              940 non-null    int64
#  8   TotalMimutes          940 non-null    int64
#  9   TotlaHours            940 non-null    int32
#  10  DayOfWeek             940 non-null    object
#  11  DayOfWeek_Num         940 non-null    int64
# dtypes: datetime64[ns](1), int32(1), int64(9), object(1)
# memory usage: 84.6+ KB

# %%
plt.figure(figsize=(8, 7))
plt.scatter(df['TotlaHours'], df['Calories'], c=df['Calories'])


Median_Hours = 24
Median_Calories =2134

plt.axhline(Median_Calories,color = 'blue',label="Median of cal")
plt.axvline(Median_Hours,color='red',label="Median of steps")

plt.xlabel('Hours')
plt.ylabel('Cal')

plt.title("cal by total steps")
plt.legend()
plt.show()

# %%
print(df.columns)
# Out:
# Index(['Id', 'Date', 'TotalSteps', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories', 'TotalMimutes',
#        'TotlaHours', 'DayOfWeek', 'DayOfWeek_Num'],
#       dtype='object')

# %%
VeryActiveMinutes = df.VeryActiveMinutes.sum()
FairActiveMinutes = df.FairlyActiveMinutes.sum()
LightlyActiveMinutes = df.LightlyActiveMinutes.sum()
SedentaryMinutes = df.SedentaryMinutes.sum()

minutes = [VeryActiveMinutes,FairActiveMinutes,LightlyActiveMinutes,SedentaryMinutes]
labels = ['VeryActiveMinutes','FairActiveMinutes','LightlyActiveMinutes','SedentaryMinutes']

plt.pie(minutes,labels=labels,autopct='%1.1f%%',explode=[0,0,0,0.1])
# Out:
# ([<matplotlib.patches.Wedge at 0x236b2ffb740>,
# ...
#  [Text(1.0983633515717721, 0.059982896929240755, 'VeryActiveMinutes'),
#   Text(1.0886022147551395, 0.1579405522030527, 'FairActiveMinutes'),
#   Text(0.8580470838875357, 0.6882987736674362, 'LightlyActiveMinutes'),
#   Text(-0.9994337278611289, -0.6641778554074256, 'SedentaryMinutes')],
#  [Text(0.5991072826755119, 0.03271794377958586, '1.7%'),
#   Text(0.5937830262300761, 0.086149392110756, '1.1%'),
#   Text(0.4680256821204739, 0.3754356947276924, '15.8%'),
#   Text(-0.5830030079189918, -0.3874370823209982, '81.3%')])
